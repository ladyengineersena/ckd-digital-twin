# %% [markdown]
# # Exploratory Data Analysis - CKD Digital Twin
#
# This notebook explores the synthetic CKD dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from src.preprocess.features import load_data

# Load synthetic data
meta, labs, meds, events = load_data("data/synthetic")

print("Metadata shape:", meta.shape)
print("Labs shape:", labs.shape)
print("Meds shape:", meds.shape)
print("Events shape:", events.shape)

# %%
# Basic statistics
print(meta.describe())
print("\nLabs summary:")
print(labs.describe())
